27876 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0413 13:26:33.574874 27876 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 36.752s
#
# OK (skipped=1)

# %%
import object_detection

# %% [markdown]
# **Download the model from the tensorflow model zoo so as to leverage transfer learning**

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#   1% [.                                                                     ]   4055040 / 244817203
#   4% [..                                                                    ]  10330112 / 244817203
#   6% [....                                                                  ]  16400384 / 244817203
#   9% [......                                                                ]  23011328 / 244817203
#  11% [........                                                              ]  28565504 / 244817203
#  14% [.........                                                             ]  34840576 / 244817203
#  16% [...........                                                           ]  40083456 / 244817203
#  18% [.............                                                         ]  46145536 / 244817203
#  21% [..............                                                        ]  52207616 / 244817203
#  23% [................                                                      ]  58294272 / 244817203
#  26% [..................                                                    ]  64888832 / 244817203
#  29% [....................                                                  ]  71278592 / 244817203
#  31% [......................                                                ]  77561856 / 244817203
#  34% [........................                                              ]  84279296 / 244817203
#  37% [.........................                                             ]  90750976 / 244817203
#  39% [...........................                                           ]  97107968 / 244817203
#  41% [.............................                                         ] 102137856 / 244817203
#  43% [..............................                                        ] 107372544 / 244817203
#  46% [................................                                      ] 112648192 / 244817203
#  48% [.................................                                     ] 118792192 / 244817203
#  50% [...................................                                   ] 124035072 / 244817203
#  52% [.....................................                                 ] 129638400 / 244817203
#  55% [......................................                                ] 135372800 / 244817203
#  57% [........................................                              ] 140025856 / 244817203
#  59% [.........................................                             ] 145694720 / 244817203
#  60% [..........................................                            ] 147931136 / 244817203
#  62% [...........................................                           ] 152985600 / 244817203
#  64% [.............................................                         ] 158662656 / 244817203
#  67% [...............................................                       ] 164478976 / 244817203
#  69% [................................................                      ] 170680320 / 244817203
#  72% [..................................................                    ] 176340992 / 244817203
#  74% [...................................................                   ] 181624832 / 244817203
#  76% [.....................................................                 ] 187547648 / 244817203
#  78% [.......................................................               ] 193183744 / 244817203
#  81% [........................................................              ] 198803456 / 244817203
#  82% [.........................................................             ] 202825728 / 244817203
#  85% [............................................................          ] 210018304 / 244817203
#  88% [.............................................................         ] 216162304 / 244817203
#  90% [...............................................................       ] 221995008 / 244817203
#  92% [.................................................................     ] 227368960 / 244817203
#  94% [..................................................................    ] 231792640 / 244817203
#  96% [...................................................................   ] 236920832 / 244817203
#  98% [..................................................................... ] 241844224 / 244817203
# 100% [......................................................................] 244817203 / 244817203
#         1 file(s) moved.
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'person', 'id':1}, {'name':'nonhuman', 'id':2}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow\scripts'...

# %%
#file_path  = os.path.join(os.getcwd(), paths['IMAGE_PATH'])
#filenames = os.listdir(file_path)
#for filename in filenames:
#    os.rename(os.path.join(file_path, filename), os.path.join(file_path, filename.replace('-', '')))

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_resnet50_v1_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 0.00039999998989515007
#          }
#        }
#        initializer {
#          truncated_normal_initializer {
#            mean: 0.0
#            stddev: 0.029999999329447746
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 0.00039999998989515007
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 256
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 64
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.03999999910593033
#          total_steps: 25000
#          warmup_learning_rate: 0.013333000242710114
#          warmup_steps: 2000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 25000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  use_bfloat16: true
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=6000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_resnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_resnet\pipeline.config --num_train_steps=6000

# %%
# !{command}
# Out:
# 2023-04-15 04:00:26.325156: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-04-15 04:00:26.325378: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-15 04:00:37.146748: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2023-04-15 04:00:37.146901: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-15 04:00:37.150095: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: Abisola
# 2023-04-15 04:00:37.150200: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: Abisola
# 2023-04-15 04:00:37.152983: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# W0415 04:00:37.154248  9528 cross_device_ops.py:1387] There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0415 04:00:37.207617  9528 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 6000
# I0415 04:00:37.223277  9528 config_util.py:552] Maybe overwriting train_steps: 6000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0415 04:00:37.223277  9528 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0415 04:00:37.254489  9528 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I0415 04:00:37.270107  9528 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I0415 04:00:37.285798  9528 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0415 04:00:37.285798  9528 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0415 04:00:37.285798  9528 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0415 04:00:37.301351  9528 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0415 04:00:37.323555  9528 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0415 04:00:44.830339  9528 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0415 04:00:48.200028  9528 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0415 04:00:50.124325  9528 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-04-15 04:00:53.255380: W tensorflow/core/framework/dataset.cc:769] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# C:\Users\Abisola\anaconda3\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0415 04:01:02.419531 13700 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0415 04:01:12.238910 14040 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2023-04-15 04:01:28.802166: W tensorflow/core/framework/dataset.cc:769] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0415 04:01:29.299665 13516 deprecation.py:554] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0415 04:01:30.474676 13516 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0415 04:01:37.133136 11664 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0415 04:01:43.875072  6852 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0415 04:01:50.300794  5872 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# INFO:tensorflow:Step 2100 per-step time 23.967s
# I0415 04:41:25.668537  9528 model_lib_v2.py:705] Step 2100 per-step time 23.967s
# INFO:tensorflow:{'Loss/classification_loss': 0.47025526,
#  'Loss/localization_loss': 0.34321398,
#  'Loss/regularization_loss': 0.2824355,
#  'Loss/total_loss': 1.0959048,
#  'learning_rate': 0.039998136}
# I0415 04:41:25.668537  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.47025526,
#  'Loss/localization_loss': 0.34321398,
#  'Loss/regularization_loss': 0.2824355,
#  'Loss/total_loss': 1.0959048,
#  'learning_rate': 0.039998136}
# INFO:tensorflow:Step 2200 per-step time 24.005s
# I0415 05:21:26.114877  9528 model_lib_v2.py:705] Step 2200 per-step time 24.005s
# INFO:tensorflow:{'Loss/classification_loss': 0.42236355,
#  'Loss/localization_loss': 0.4242074,
#  'Loss/regularization_loss': 0.28084862,
#  'Loss/total_loss': 1.1274195,
#  'learning_rate': 0.039992537}
# I0415 05:21:26.114877  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.42236355,
#  'Loss/localization_loss': 0.4242074,
#  'Loss/regularization_loss': 0.28084862,
#  'Loss/total_loss': 1.1274195,
#  'learning_rate': 0.039992537}
# INFO:tensorflow:Step 2300 per-step time 24.161s
# I0415 06:01:45.554544  9528 model_lib_v2.py:705] Step 2300 per-step time 24.161s
# INFO:tensorflow:{'Loss/classification_loss': 0.51943195,
#  'Loss/localization_loss': 0.34942728,
#  'Loss/regularization_loss': 0.27968755,
#  'Loss/total_loss': 1.1485468,
#  'learning_rate': 0.03998321}
# I0415 06:01:45.554544  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.51943195,
#  'Loss/localization_loss': 0.34942728,
#  'Loss/regularization_loss': 0.27968755,
#  'Loss/total_loss': 1.1485468,
#  'learning_rate': 0.03998321}
# INFO:tensorflow:Step 2400 per-step time 24.222s
# I0415 06:42:04.413111  9528 model_lib_v2.py:705] Step 2400 per-step time 24.222s
# INFO:tensorflow:{'Loss/classification_loss': 0.6097234,
#  'Loss/localization_loss': 0.40671638,
#  'Loss/regularization_loss': 0.2788553,
#  'Loss/total_loss': 1.295295,
#  'learning_rate': 0.039970152}
# I0415 06:42:04.413111  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.6097234,
#  'Loss/localization_loss': 0.40671638,
#  'Loss/regularization_loss': 0.2788553,
#  'Loss/total_loss': 1.295295,
#  'learning_rate': 0.039970152}
# INFO:tensorflow:Step 2500 per-step time 24.375s
# I0415 07:22:41.913120  9528 model_lib_v2.py:705] Step 2500 per-step time 24.375s
# INFO:tensorflow:{'Loss/classification_loss': 0.38105425,
#  'Loss/localization_loss': 0.35013878,
#  'Loss/regularization_loss': 0.27845836,
#  'Loss/total_loss': 1.0096514,
#  'learning_rate': 0.039953373}
# I0415 07:22:41.913120  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.38105425,
#  'Loss/localization_loss': 0.35013878,
#  'Loss/regularization_loss': 0.27845836,
#  'Loss/total_loss': 1.0096514,
#  'learning_rate': 0.039953373}
# INFO:tensorflow:Step 2600 per-step time 24.381s
# I0415 08:03:20.305185  9528 model_lib_v2.py:705] Step 2600 per-step time 24.381s
# INFO:tensorflow:{'Loss/classification_loss': 0.3293158,
#  'Loss/localization_loss': 0.18914123,
#  'Loss/regularization_loss': 0.27828926,
#  'Loss/total_loss': 0.7967463,
#  'learning_rate': 0.03993287}
# I0415 08:03:20.305185  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.3293158,
#  'Loss/localization_loss': 0.18914123,
#  'Loss/regularization_loss': 0.27828926,
#  'Loss/total_loss': 0.7967463,
#  'learning_rate': 0.03993287}
# INFO:tensorflow:Step 2700 per-step time 25.562s
# I0415 08:45:56.233046  9528 model_lib_v2.py:705] Step 2700 per-step time 25.562s
# INFO:tensorflow:{'Loss/classification_loss': 0.3524543,
#  'Loss/localization_loss': 0.31363112,
#  'Loss/regularization_loss': 0.27773124,
#  'Loss/total_loss': 0.94381666,
#  'learning_rate': 0.039908648}
# I0415 08:45:56.233046  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.3524543,
#  'Loss/localization_loss': 0.31363112,
#  'Loss/regularization_loss': 0.27773124,
#  'Loss/total_loss': 0.94381666,
#  'learning_rate': 0.039908648}
# INFO:tensorflow:Step 2800 per-step time 24.903s
# I0415 09:27:26.563715  9528 model_lib_v2.py:705] Step 2800 per-step time 24.903s
# INFO:tensorflow:{'Loss/classification_loss': 0.28994074,
#  'Loss/localization_loss': 0.16887654,
#  'Loss/regularization_loss': 0.27652824,
#  'Loss/total_loss': 0.7353455,
#  'learning_rate': 0.039880715}
# I0415 09:27:26.567704  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.28994074,
#  'Loss/localization_loss': 0.16887654,
#  'Loss/regularization_loss': 0.27652824,
#  'Loss/total_loss': 0.7353455,
#  'learning_rate': 0.039880715}
# INFO:tensorflow:Step 2900 per-step time 24.692s
# I0415 10:08:36.014626  9528 model_lib_v2.py:705] Step 2900 per-step time 24.692s
# INFO:tensorflow:{'Loss/classification_loss': 0.3443938,
#  'Loss/localization_loss': 0.2143922,
#  'Loss/regularization_loss': 0.27637532,
#  'Loss/total_loss': 0.8351613,
#  'learning_rate': 0.039849065}
# I0415 10:08:36.014626  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.3443938,
#  'Loss/localization_loss': 0.2143922,
#  'Loss/regularization_loss': 0.27637532,
#  'Loss/total_loss': 0.8351613,
#  'learning_rate': 0.039849065}
# INFO:tensorflow:Step 3000 per-step time 25.455s
# I0415 10:51:01.294496  9528 model_lib_v2.py:705] Step 3000 per-step time 25.455s
# INFO:tensorflow:{'Loss/classification_loss': 0.3118642,
#  'Loss/localization_loss': 0.16417328,
#  'Loss/regularization_loss': 0.27578312,
#  'Loss/total_loss': 0.75182056,
#  'learning_rate': 0.03981372}
# I0415 10:51:01.294496  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.3118642,
#  'Loss/localization_loss': 0.16417328,
#  'Loss/regularization_loss': 0.27578312,
#  'Loss/total_loss': 0.75182056,
#  'learning_rate': 0.03981372}
# INFO:tensorflow:Step 3100 per-step time 25.810s
# I0415 11:34:02.293558  9528 model_lib_v2.py:705] Step 3100 per-step time 25.810s
# INFO:tensorflow:{'Loss/classification_loss': 0.2939661,
#  'Loss/localization_loss': 0.2963447,
#  'Loss/regularization_loss': 0.27425444,
#  'Loss/total_loss': 0.86456525,
#  'learning_rate': 0.03977467}
# I0415 11:34:02.293558  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.2939661,
#  'Loss/localization_loss': 0.2963447,
#  'Loss/regularization_loss': 0.27425444,
#  'Loss/total_loss': 0.86456525,
#  'learning_rate': 0.03977467}
# INFO:tensorflow:Step 3200 per-step time 24.577s
# I0415 12:15:00.038381  9528 model_lib_v2.py:705] Step 3200 per-step time 24.577s
# INFO:tensorflow:{'Loss/classification_loss': 0.2792491,
#  'Loss/localization_loss': 0.22883384,
#  'Loss/regularization_loss': 0.2750417,
#  'Loss/total_loss': 0.7831246,
#  'learning_rate': 0.03973194}
# I0415 12:15:00.038381  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.2792491,
#  'Loss/localization_loss': 0.22883384,
#  'Loss/regularization_loss': 0.2750417,
#  'Loss/total_loss': 0.7831246,
#  'learning_rate': 0.03973194}
# INFO:tensorflow:Step 3300 per-step time 24.846s
# I0415 12:56:24.574047  9528 model_lib_v2.py:705] Step 3300 per-step time 24.846s
# INFO:tensorflow:{'Loss/classification_loss': 0.3916777,
#  'Loss/localization_loss': 0.20431994,
#  'Loss/regularization_loss': 0.27409297,
#  'Loss/total_loss': 0.8700906,
#  'learning_rate': 0.03968552}
# I0415 12:56:24.574047  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.3916777,
#  'Loss/localization_loss': 0.20431994,
#  'Loss/regularization_loss': 0.27409297,
#  'Loss/total_loss': 0.8700906,
#  'learning_rate': 0.03968552}
# INFO:tensorflow:Step 3400 per-step time 24.962s
# I0415 13:38:00.731933  9528 model_lib_v2.py:705] Step 3400 per-step time 24.962s
# INFO:tensorflow:{'Loss/classification_loss': 0.24996501,
#  'Loss/localization_loss': 0.17811683,
#  'Loss/regularization_loss': 0.27322072,
#  'Loss/total_loss': 0.7013025,
#  'learning_rate': 0.039635435}
# I0415 13:38:00.731933  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.24996501,
#  'Loss/localization_loss': 0.17811683,
#  'Loss/regularization_loss': 0.27322072,
#  'Loss/total_loss': 0.7013025,
#  'learning_rate': 0.039635435}
# INFO:tensorflow:Step 3500 per-step time 24.763s
# I0415 14:19:17.068019  9528 model_lib_v2.py:705] Step 3500 per-step time 24.763s
# INFO:tensorflow:{'Loss/classification_loss': 0.32007733,
#  'Loss/localization_loss': 0.350013,
#  'Loss/regularization_loss': 0.2723179,
#  'Loss/total_loss': 0.9424082,
#  'learning_rate': 0.03958168}
# I0415 14:19:17.068019  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.32007733,
#  'Loss/localization_loss': 0.350013,
#  'Loss/regularization_loss': 0.2723179,
#  'Loss/total_loss': 0.9424082,
#  'learning_rate': 0.03958168}
# INFO:tensorflow:Step 3600 per-step time 24.569s
# I0415 15:00:17.456027  9528 model_lib_v2.py:705] Step 3600 per-step time 24.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.31628442,
#  'Loss/localization_loss': 0.34582683,
#  'Loss/regularization_loss': 0.27157968,
#  'Loss/total_loss': 0.9336909,
#  'learning_rate': 0.039524276}
# I0415 15:00:17.456027  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.31628442,
#  'Loss/localization_loss': 0.34582683,
#  'Loss/regularization_loss': 0.27157968,
#  'Loss/total_loss': 0.9336909,
#  'learning_rate': 0.039524276}
# INFO:tensorflow:Step 3700 per-step time 24.617s
# I0415 15:41:15.710179  9528 model_lib_v2.py:705] Step 3700 per-step time 24.617s
# INFO:tensorflow:{'Loss/classification_loss': 0.21228202,
#  'Loss/localization_loss': 0.14918055,
#  'Loss/regularization_loss': 0.27154848,
#  'Loss/total_loss': 0.63301104,
#  'learning_rate': 0.03946323}
# I0415 15:41:15.710179  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.21228202,
#  'Loss/localization_loss': 0.14918055,
#  'Loss/regularization_loss': 0.27154848,
#  'Loss/total_loss': 0.63301104,
#  'learning_rate': 0.03946323}
# INFO:tensorflow:Step 3800 per-step time 25.383s
# I0415 16:23:37.354312  9528 model_lib_v2.py:705] Step 3800 per-step time 25.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.34845924,
#  'Loss/localization_loss': 0.12987544,
#  'Loss/regularization_loss': 0.27147788,
#  'Loss/total_loss': 0.74981254,
#  'learning_rate': 0.039398547}
# I0415 16:23:37.354312  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.34845924,
#  'Loss/localization_loss': 0.12987544,
#  'Loss/regularization_loss': 0.27147788,
#  'Loss/total_loss': 0.74981254,
#  'learning_rate': 0.039398547}
# INFO:tensorflow:Step 3900 per-step time 24.505s
# I0415 17:04:27.831056  9528 model_lib_v2.py:705] Step 3900 per-step time 24.505s
# INFO:tensorflow:{'Loss/classification_loss': 0.33226976,
#  'Loss/localization_loss': 0.26295194,
#  'Loss/regularization_loss': 0.27055252,
#  'Loss/total_loss': 0.8657743,
#  'learning_rate': 0.039330248}
# I0415 17:04:27.831056  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.33226976,
#  'Loss/localization_loss': 0.26295194,
#  'Loss/regularization_loss': 0.27055252,
#  'Loss/total_loss': 0.8657743,
#  'learning_rate': 0.039330248}
# INFO:tensorflow:Step 4000 per-step time 24.553s
# I0415 17:45:20.028635  9528 model_lib_v2.py:705] Step 4000 per-step time 24.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.44270676,
#  'Loss/localization_loss': 0.23523009,
#  'Loss/regularization_loss': 0.26922107,
#  'Loss/total_loss': 0.9471579,
#  'learning_rate': 0.039258346}
# I0415 17:45:20.028635  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.44270676,
#  'Loss/localization_loss': 0.23523009,
#  'Loss/regularization_loss': 0.26922107,
#  'Loss/total_loss': 0.9471579,
#  'learning_rate': 0.039258346}
# INFO:tensorflow:Step 4100 per-step time 24.771s
# I0415 18:26:36.814500  9528 model_lib_v2.py:705] Step 4100 per-step time 24.771s
# INFO:tensorflow:{'Loss/classification_loss': 0.21892081,
#  'Loss/localization_loss': 0.15027742,
#  'Loss/regularization_loss': 0.26843554,
#  'Loss/total_loss': 0.6376338,
#  'learning_rate': 0.03918285}
# I0415 18:26:36.814500  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.21892081,
#  'Loss/localization_loss': 0.15027742,
#  'Loss/regularization_loss': 0.26843554,
#  'Loss/total_loss': 0.6376338,
#  'learning_rate': 0.03918285}
# INFO:tensorflow:Step 4200 per-step time 24.686s
# I0415 19:07:48.826067  9528 model_lib_v2.py:705] Step 4200 per-step time 24.686s
# INFO:tensorflow:{'Loss/classification_loss': 0.34060797,
#  'Loss/localization_loss': 0.45791024,
#  'Loss/regularization_loss': 0.26718688,
#  'Loss/total_loss': 1.0657051,
#  'learning_rate': 0.03910377}
# I0415 19:07:48.826067  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.34060797,
#  'Loss/localization_loss': 0.45791024,
#  'Loss/regularization_loss': 0.26718688,
#  'Loss/total_loss': 1.0657051,
#  'learning_rate': 0.03910377}
# INFO:tensorflow:Step 4300 per-step time 24.730s
# I0415 19:48:58.362117  9528 model_lib_v2.py:705] Step 4300 per-step time 24.730s
# INFO:tensorflow:{'Loss/classification_loss': 0.4117581,
#  'Loss/localization_loss': 0.1993568,
#  'Loss/regularization_loss': 0.2676287,
#  'Loss/total_loss': 0.8787436,
#  'learning_rate': 0.039021127}
# I0415 19:48:58.362117  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.4117581,
#  'Loss/localization_loss': 0.1993568,
#  'Loss/regularization_loss': 0.2676287,
#  'Loss/total_loss': 0.8787436,
#  'learning_rate': 0.039021127}
# INFO:tensorflow:Step 4400 per-step time 24.722s
# I0415 20:30:10.519533  9528 model_lib_v2.py:705] Step 4400 per-step time 24.722s
# INFO:tensorflow:{'Loss/classification_loss': 0.26078963,
#  'Loss/localization_loss': 0.24816592,
#  'Loss/regularization_loss': 0.26653782,
#  'Loss/total_loss': 0.7754933,
#  'learning_rate': 0.03893494}
# I0415 20:30:10.519533  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.26078963,
#  'Loss/localization_loss': 0.24816592,
#  'Loss/regularization_loss': 0.26653782,
#  'Loss/total_loss': 0.7754933,
#  'learning_rate': 0.03893494}
# INFO:tensorflow:Step 4500 per-step time 24.785s
# I0415 21:11:29.042040  9528 model_lib_v2.py:705] Step 4500 per-step time 24.785s
# INFO:tensorflow:{'Loss/classification_loss': 0.30215102,
#  'Loss/localization_loss': 0.28573814,
#  'Loss/regularization_loss': 0.26589847,
#  'Loss/total_loss': 0.8537876,
#  'learning_rate': 0.03884522}
# I0415 21:11:29.042040  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.30215102,
#  'Loss/localization_loss': 0.28573814,
#  'Loss/regularization_loss': 0.26589847,
#  'Loss/total_loss': 0.8537876,
#  'learning_rate': 0.03884522}
# INFO:tensorflow:Step 4600 per-step time 24.723s
# I0415 21:52:44.695977  9528 model_lib_v2.py:705] Step 4600 per-step time 24.723s
# INFO:tensorflow:{'Loss/classification_loss': 0.25911647,
#  'Loss/localization_loss': 0.24410258,
#  'Loss/regularization_loss': 0.26452854,
#  'Loss/total_loss': 0.7677476,
#  'learning_rate': 0.03875198}
# I0415 21:52:44.695977  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.25911647,
#  'Loss/localization_loss': 0.24410258,
#  'Loss/regularization_loss': 0.26452854,
#  'Loss/total_loss': 0.7677476,
#  'learning_rate': 0.03875198}
# INFO:tensorflow:Step 4700 per-step time 24.861s
# I0415 22:34:07.449901  9528 model_lib_v2.py:705] Step 4700 per-step time 24.861s
# INFO:tensorflow:{'Loss/classification_loss': 0.36099872,
#  'Loss/localization_loss': 0.24374561,
#  'Loss/regularization_loss': 0.26400584,
#  'Loss/total_loss': 0.8687502,
#  'learning_rate': 0.038655244}
# I0415 22:34:07.449901  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.36099872,
#  'Loss/localization_loss': 0.24374561,
#  'Loss/regularization_loss': 0.26400584,
#  'Loss/total_loss': 0.8687502,
#  'learning_rate': 0.038655244}
# INFO:tensorflow:Step 4800 per-step time 24.646s
# I0415 23:15:12.351457  9528 model_lib_v2.py:705] Step 4800 per-step time 24.646s
# INFO:tensorflow:{'Loss/classification_loss': 0.29622802,
#  'Loss/localization_loss': 0.36309448,
#  'Loss/regularization_loss': 0.2639833,
#  'Loss/total_loss': 0.92330587,
#  'learning_rate': 0.038555026}
# I0415 23:15:12.351457  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.29622802,
#  'Loss/localization_loss': 0.36309448,
#  'Loss/regularization_loss': 0.2639833,
#  'Loss/total_loss': 0.92330587,
#  'learning_rate': 0.038555026}
# INFO:tensorflow:Step 4900 per-step time 24.686s
# I0415 23:56:20.658373  9528 model_lib_v2.py:705] Step 4900 per-step time 24.686s
# INFO:tensorflow:{'Loss/classification_loss': 0.19734716,
#  'Loss/localization_loss': 0.13044354,
#  'Loss/regularization_loss': 0.26272035,
#  'Loss/total_loss': 0.5905111,
#  'learning_rate': 0.038451348}
# I0415 23:56:20.658373  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.19734716,
#  'Loss/localization_loss': 0.13044354,
#  'Loss/regularization_loss': 0.26272035,
#  'Loss/total_loss': 0.5905111,
#  'learning_rate': 0.038451348}
# INFO:tensorflow:Step 5000 per-step time 24.583s
# I0416 00:37:22.302071  9528 model_lib_v2.py:705] Step 5000 per-step time 24.583s
# INFO:tensorflow:{'Loss/classification_loss': 0.22390482,
#  'Loss/localization_loss': 0.2278846,
#  'Loss/regularization_loss': 0.2618643,
#  'Loss/total_loss': 0.71365374,
#  'learning_rate': 0.038344227}
# I0416 00:37:22.302071  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.22390482,
#  'Loss/localization_loss': 0.2278846,
#  'Loss/regularization_loss': 0.2618643,
#  'Loss/total_loss': 0.71365374,
#  'learning_rate': 0.038344227}
# INFO:tensorflow:Step 5100 per-step time 24.698s
# I0416 01:18:28.950269  9528 model_lib_v2.py:705] Step 5100 per-step time 24.698s
# INFO:tensorflow:{'Loss/classification_loss': 0.28679392,
#  'Loss/localization_loss': 0.23909281,
#  'Loss/regularization_loss': 0.26193509,
#  'Loss/total_loss': 0.7878218,
#  'learning_rate': 0.03823368}
# I0416 01:18:28.950269  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.28679392,
#  'Loss/localization_loss': 0.23909281,
#  'Loss/regularization_loss': 0.26193509,
#  'Loss/total_loss': 0.7878218,
#  'learning_rate': 0.03823368}
# INFO:tensorflow:Step 5200 per-step time 24.787s
# I0416 01:59:47.697136  9528 model_lib_v2.py:705] Step 5200 per-step time 24.787s
# INFO:tensorflow:{'Loss/classification_loss': 0.24212201,
#  'Loss/localization_loss': 0.1574906,
#  'Loss/regularization_loss': 0.26100415,
#  'Loss/total_loss': 0.66061676,
#  'learning_rate': 0.038119733}
# I0416 01:59:47.697136  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.24212201,
#  'Loss/localization_loss': 0.1574906,
#  'Loss/regularization_loss': 0.26100415,
#  'Loss/total_loss': 0.66061676,
#  'learning_rate': 0.038119733}
# INFO:tensorflow:Step 5300 per-step time 25.183s
# I0416 02:41:45.764066  9528 model_lib_v2.py:705] Step 5300 per-step time 25.183s
# INFO:tensorflow:{'Loss/classification_loss': 0.1902686,
#  'Loss/localization_loss': 0.12618877,
#  'Loss/regularization_loss': 0.26155794,
#  'Loss/total_loss': 0.5780153,
#  'learning_rate': 0.03800241}
# I0416 02:41:45.765063  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.1902686,
#  'Loss/localization_loss': 0.12618877,
#  'Loss/regularization_loss': 0.26155794,
#  'Loss/total_loss': 0.5780153,
#  'learning_rate': 0.03800241}
# INFO:tensorflow:Step 5400 per-step time 24.815s
# I0416 03:23:07.230469  9528 model_lib_v2.py:705] Step 5400 per-step time 24.815s
# INFO:tensorflow:{'Loss/classification_loss': 0.34332266,
#  'Loss/localization_loss': 0.29035467,
#  'Loss/regularization_loss': 0.26123035,
#  'Loss/total_loss': 0.89490765,
#  'learning_rate': 0.037881725}
# I0416 03:23:07.230469  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.34332266,
#  'Loss/localization_loss': 0.29035467,
#  'Loss/regularization_loss': 0.26123035,
#  'Loss/total_loss': 0.89490765,
#  'learning_rate': 0.037881725}
# INFO:tensorflow:Step 5500 per-step time 24.668s
# I0416 04:04:14.385161  9528 model_lib_v2.py:705] Step 5500 per-step time 24.668s
# INFO:tensorflow:{'Loss/classification_loss': 0.33182964,
#  'Loss/localization_loss': 0.18255635,
#  'Loss/regularization_loss': 0.26032215,
#  'Loss/total_loss': 0.7747081,
#  'learning_rate': 0.037757702}
# I0416 04:04:14.385161  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.33182964,
#  'Loss/localization_loss': 0.18255635,
#  'Loss/regularization_loss': 0.26032215,
#  'Loss/total_loss': 0.7747081,
#  'learning_rate': 0.037757702}
# INFO:tensorflow:Step 5600 per-step time 24.811s
# I0416 04:45:35.495346  9528 model_lib_v2.py:705] Step 5600 per-step time 24.811s
# INFO:tensorflow:{'Loss/classification_loss': 0.20521477,
#  'Loss/localization_loss': 0.074648686,
#  'Loss/regularization_loss': 0.26068237,
#  'Loss/total_loss': 0.5405458,
#  'learning_rate': 0.03763037}
# I0416 04:45:35.503362  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.20521477,
#  'Loss/localization_loss': 0.074648686,
#  'Loss/regularization_loss': 0.26068237,
#  'Loss/total_loss': 0.5405458,
#  'learning_rate': 0.03763037}
# INFO:tensorflow:Step 5700 per-step time 24.718s
# I0416 05:26:47.068916  9528 model_lib_v2.py:705] Step 5700 per-step time 24.718s
# INFO:tensorflow:{'Loss/classification_loss': 0.39304417,
#  'Loss/localization_loss': 0.21314034,
#  'Loss/regularization_loss': 0.25999302,
#  'Loss/total_loss': 0.86617756,
#  'learning_rate': 0.03749975}
# I0416 05:26:47.068916  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.39304417,
#  'Loss/localization_loss': 0.21314034,
#  'Loss/regularization_loss': 0.25999302,
#  'Loss/total_loss': 0.86617756,
#  'learning_rate': 0.03749975}
# INFO:tensorflow:Step 5800 per-step time 24.521s
# I0416 06:07:39.476327  9528 model_lib_v2.py:705] Step 5800 per-step time 24.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.30857566,
#  'Loss/localization_loss': 0.15840554,
#  'Loss/regularization_loss': 0.26086494,
#  'Loss/total_loss': 0.72784615,
#  'learning_rate': 0.037365858}
# I0416 06:07:39.476327  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.30857566,
#  'Loss/localization_loss': 0.15840554,
#  'Loss/regularization_loss': 0.26086494,
#  'Loss/total_loss': 0.72784615,
#  'learning_rate': 0.037365858}
# INFO:tensorflow:Step 5900 per-step time 24.526s
# I0416 06:48:31.777944  9528 model_lib_v2.py:705] Step 5900 per-step time 24.526s
# INFO:tensorflow:{'Loss/classification_loss': 0.32900974,
#  'Loss/localization_loss': 0.17147523,
#  'Loss/regularization_loss': 0.26000184,
#  'Loss/total_loss': 0.7604868,
#  'learning_rate': 0.03722873}
# I0416 06:48:31.777944  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.32900974,
#  'Loss/localization_loss': 0.17147523,
#  'Loss/regularization_loss': 0.26000184,
#  'Loss/total_loss': 0.7604868,
#  'learning_rate': 0.03722873}
# INFO:tensorflow:Step 6000 per-step time 24.569s
# I0416 07:29:28.653620  9528 model_lib_v2.py:705] Step 6000 per-step time 24.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.20107646,
#  'Loss/localization_loss': 0.14803031,
#  'Loss/regularization_loss': 0.26071241,
#  'Loss/total_loss': 0.6098192,
#  'learning_rate': 0.037088387}
# I0416 07:29:28.654612  9528 model_lib_v2.py:708] {'Loss/classification_loss': 0.20107646,
#  'Loss/localization_loss': 0.14803031,
#  'Loss/regularization_loss': 0.26071241,
#  'Loss/total_loss': 0.6098192,
#  'learning_rate': 0.037088387}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_resnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_resnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_resnet

# %%
# !{command}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.31s).
# Accumulating evaluation results...
# DONE (t=0.25s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.529
# 2023-04-16 09:07:21.726035: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-04-16 09:07:21.726086: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-16 09:07:29.334137: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2023-04-16 09:07:29.334169: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-16 09:07:29.338521: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: Abisola
# 2023-04-16 09:07:29.338618: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: Abisola
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0416 09:07:29.335661  9428 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0416 09:07:29.335661  9428 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0416 09:07:29.335661  9428 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0416 09:07:29.335661  9428 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0416 09:07:29.335661  9428 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-04-16 09:07:29.346265: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# I0416 09:07:29.398151  9428 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# I0416 09:07:29.398151  9428 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0416 09:07:29.398151  9428 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0416 09:07:29.398151  9428 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0416 09:07:29.398151  9428 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0416 09:07:29.413809  9428 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0416 09:07:34.423318  9428 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0416 09:07:35.987195  9428 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_resnet
# I0416 09:07:39.011034  9428 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_resnet
# INFO:tensorflow:Found new checkpoint at Tensorflow\workspace\models\my_ssd_resnet\ckpt-7
# I0416 09:07:39.011034  9428 checkpoint_utils.py:151] Found new checkpoint at Tensorflow\workspace\models\my_ssd_resnet\ckpt-7
# C:\Users\Abisola\anaconda3\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0416 09:07:46.373790  9428 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0416 09:08:01.868281  9428 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0416 09:08:08.102876  9428 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0416 09:08:08.124989  9428 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0416 09:08:08.442013  9428 deprecation.py:350] From C:\Users\Abisola\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0416 09:10:25.360557  9428 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0416 09:12:45.660203  9428 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 226 images.
# I0416 09:13:21.374147  9428 coco_evaluation.py:293] Performing evaluation on 226 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0416 09:13:21.374147  9428 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0416 09:13:21.383152  9428 coco_tools.py:138] DONE (t=0.01s)
# INFO:tensorflow:Eval metrics at step 6000
# I0416 09:13:22.991328  9428 model_lib_v2.py:1015] Eval metrics at step 6000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.147648
# I0416 09:13:23.111833  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.147648
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.368343
# I0416 09:13:23.111833  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.368343
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.088322
# I0416 09:13:23.111833  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.088322
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.081470
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.081470
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.172562
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.172562
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.144085
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.144085
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.349061
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.349061
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.485525
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.485525
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.330518
# I0416 09:13:23.127514  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.330518
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.529038
# I0416 09:13:23.159190  9428 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.529038
# INFO:tensorflow:	+ Loss/localization_loss: 0.352555
# I0416 09:13:23.159190  9428 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.352555
# INFO:tensorflow:	+ Loss/classification_loss: 0.455643
# I0416 09:13:23.159190  9428 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.455643
# INFO:tensorflow:	+ Loss/regularization_loss: 0.260695
# I0416 09:13:23.159190  9428 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.260695
# INFO:tensorflow:	+ Loss/total_loss: 1.068894
# I0416 09:13:23.159190  9428 model_lib_v2.py:1018] 	+ Loss/total_loss: 1.068894
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_resnet
# I0416 09:13:23.332997  9428 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_resnet
# INFO:tensorflow:Timed-out waiting for a checkpoint.
# I0416 13:13:23.319061  9428 checkpoint_utils.py:205] Timed-out waiting for a checkpoint.

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %% [raw]
# import os
# import tensorflow as tf
# from object_detection.utils import label_map_util
# from object_detection.utils import visualization_utils as viz_utils
# from object_detection.builders import model_builder
# from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'livelong.8f8cf04a-bf25-11ed-833b-b4d5bdff0b35.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip install opencv-python-headless

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
